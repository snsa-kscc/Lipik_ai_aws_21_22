# %% [markdown]
# # open CV vježbe

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('kamera1.jpg')
img[55,55]
# Out:
# array([22, 51, 72], dtype=uint8)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_img)
